# %%
import pandas as pd

# %%
# data_dtm = pd.read_pickle('dtm.pkl')
# data_dtm = data_dtm.transpose()

# %%
df_billText = pd.read_csv('billText_Processed_n.csv',index_col=0)

# %%
df_billText.head()
# Out:
#       bill_id                                         long_title bill_status
# 0  17SBN-2235                      fiscal regime mining industry     Pending
# 1  17SBN-2234  sale certain land barangay city university cit...      Passed
# 2  17SBN-2233  excise tax tobacco tax incremental tobacco exc...      Passed
# 3  17SBN-2232  institutionalization development training orga...     Pending
# 4  17SBN-2231                                               bank     Pending

# %%
wordGroups = df_billText.long_title.tolist()
bill_words = [wordGroup.split(' ') for wordGroup in wordGroups]
flat_list = [item for sublist in bill_words for item in sublist]

# %%
flat_list
# Out:
# ['fiscal',
#  'regime',
#  'mining',
#  'industry',
#  'sale',
#  'certain',
#  'land',
#  'barangay',
#  'city',
#  'university',
#  'city',
#  'university',
#  'charter',
#  'excise',
#  'tax',
#  'tobacco',
#  'tax',
#  'incremental',
#  'tobacco',
#  'excise',
#  'tax',
#  'human',
#  'resource',
#  'development',
#  'health',
#  'internal',
#  'revenue',
#  'institutionalization',
#  'development',
#  'training',
#  'organization',
#  'administration',
#  'basic',
#  'reserve',
#  'corp',
#  'public',
#  'private',
#  'educational',
#  'citizen',
#  'force',
#  'reservist',
#  'service',
#  'bank',
#  'day',
#  'remembrance',
#  'road',
#  'crash',
#  'third',
#  'day',
#  'remembrance',
#  'road',
#  'crash',
#  'nature',
#  'park',
#  'barangay',
#  'city',
#  'province',
#  'responsible',
#  'zone',
#  'foreign',
#  'disclosure',
#  'pertinent',
#  'secrecy',
#  'evaluation',
#  'protecting',
#  'child',
#  'marriage',
#  'illegal',
#  'energy',
#  'consumer',
#  'advocate',
#  'sport',
#  'academy',
#  'training',
#  'center',
#  'barangay',
#  'province',
#  'toll',
#  'certain',
#  'participation',
#  'civil',
#  'society',
#  'preparation',
#  'authorization',
#  'process',
#  'annual',
#  'budget',
#  'effective',
#  'total',
#  'electrification',
#  'unserved',
#  'memorial',
#  'medical',
#  'center',
#  'city',
#  'medical',
#  'center',
#  'department',
#  'water',
#  'irrigation',
#  'sewage',
#  'sanitation',
#  'resource',
#  'management',
#  'basic',
#  'first',
#  'aid',
#  'training',
#  'reorganization',
#  'reform',
#  'structure',
#  'uniformed',
#  'bureau',
#  'fire',
#  'protection',
#  'certain',
#  'police',
#  'reform',
#  'reorganization',
#  'social',
#  'pension',
#  'senior',
#  'coverage',
#  'senior',
#  'measurement',
#  'system',
#  'measurement',
#  'institute',
#  'public',
#  'utility',
#  'land',
#  'transportation',
#  'traffic',
#  'bed',
#  'capacity',
#  'medical',
#  'center',
#  'service',
#  'professional',
#  'health',
#  'care',
#  'therein',
#  'special',
#  'pursuant',
#  'motor',
#  'vehicle',
#  'charge',
#  'general',
#  'base',
#  'conversion',
#  'development',
#  'base',
#  'conversion',
#  'development',
#  'commission',
#  'election',
#  'system',
#  'local',
#  'subsequent',
#  'local',
#  'electoral',
#  'transparency',
#  'credibility',
#  'fairness',
#  'accuracy',
#  'related',
#  'election',
#  'labor',
#  'rationalization',
#  'wage',
#  'industrial',
#  'basis',
#  'certain',
#  'state',
#  'people',
#  'terrorism',
#  'organic',
#  'agriculture',
#  'bed',
#  'capacity',
#  'medical',
#  'center',
#  'service',
#  'professional',
#  'health',
#  'care',
#  'therein',
#  'special',
#  'working',
#  'holiday',
#  'entire',
#  'country',
#  'historic',
#  'decision',
#  'permanent',
#  'court',
#  'arbitration',
#  'favor',
#  'sovereignty',
#  'west',
#  'sea',
#  'encouraging',
#  'volunteerism',
#  'liability',
#  'regulation',
#  'social',
#  'welfare',
#  'development',
#  'youth',
#  'social',
#  'welfare',
#  'scope',
#  'reformation',
#  'rehabilitation',
#  'conflict',
#  'juvenile',
#  'justice',
#  'welfare',
#  'internal',
#  'revenue',
#  'certain',
#  'court',
#  'community',
#  'service',
#  'lieu',
#  'imprisonment',
#  'chapter',
#  'book',
#  'new',
#  'certain',
#  'consumer',
#  'mental',
#  'health',
#  'tax',
#  'internal',
#  'revenue',
#  'sex',
#  'plain',
#  'tobacco',
#  'local',
#  'local',
#  'least',
#  'ten',
#  'share',
#  'internal',
#  'revenue',
#  'allotment',
#  'administrative',
#  'procurement',
#  'reform',
#  'bed',
#  'capacity',
#  'memorial',
#  'hospital',
#  'medical',
#  'center',
#  'city',
#  'increase',
#  'medical',
#  'nonmedical',
#  'personnel',
#  'hospital',
#  'city',
#  'general',
#  'hospital',
#  'general',
#  'hospital',
#  'capacity',
#  'surveillance',
#  'response',
#  'notifiable',
#  'health',
#  'public',
#  'health',
#  'concern',
#  'communicable',
#  'appropriate',
#  'civil',
#  'service',
#  'eligibility',
#  'reform',
#  'system',
#  'additional',
#  'regional',
#  'trial',
#  'court',
#  'judicial',
#  'region',
#  'province',
#  'judiciary',
#  'reorganization',
#  'rubber',
#  'industry',
#  'rubber',
#  'industry',
#  'development',
#  'board',
#  'position',
#  'mandatory',
#  'city',
#  'provincial',
#  'local',
#  'public',
#  'utility',
#  'land',
#  'transportation',
#  'traffic',
#  'bed',
#  'capacity',
#  'memorial',
#  'general',
#  'hospital',
#  'professional',
#  'health',
#  'care',
#  'increase',
#  'medical',
#  'personnel',
#  'district',
#  'hospital',
#  'province',
#  'level',
#  'general',
#  'hospital',
#  'island',
#  'medical',
#  'center',
#  'excise',
#  'tax',
#  'tobacco',
#  'tax',
#  'reform',
#  'comprehensive',
#  'atomic',
#  'regulation',
#  'atomic',
#  'regulatory',
#  'commission',
#  'informal',
#  'economy',
#  'recognition',
#  'integration',
#  'transition',
#  'formal',
#  'economy',
#  'safety',
#  'cleanliness',
#  'public',
#  'indoor',
#  'play',
#  'public',
#  'utility',
#  'land',
#  'transportation',
#  'traffic',
#  'system',
#  'strengthening',
#  'warehouse',
#  'receipt',
#  'legal',
#  'framework',
#  'trade',
#  'commerce',
#  'related',
#  'baby',
#  'food',
#  'child',
#  'care',
#  'replacement',
#  'greater',
#  'development',
#  'authority',
#  'international',
#  'airport',
#  'authority',
#  'asset',
#  'international',
#  'airport',
#  'authority',
#  'authority',
#  'power',
#  'international',
#  'airport',
#  'wealth',
#  'generation',
#  'access',
#  'utilization',
#  'genetic',
#  'commission',
#  'disability',
#  'system',
#  'organ',
#  'tissue',
#  'donation',
#  'right',
#  'health',
#  'entrepreneurship',
#  'small',
#  'medium',
#  'small',
#  'medium',
#  'petroleum',
#  'tax',
#  'internal',
#  'revenue',
#  'money',
#  'overseas',
#  'disclosure',
#  'finance',
#  'connection',
#  'money',
#  'transfer',
#  'strict',
#  'adherence',
#  'transfer',
#  'village',
#  'city',
#  'province',
#  'important',
#  'cultural',
#  'property',
#  'public',
#  'dominion',
#  'custody',
#  'hospital',
#  'medical',
#  'clinic',
#  'funeral',
#  'parlor',
#  'morgue',
#  'similar',
#  'ground',
#  'nonpayment',
#  'hospital',
#  'medical',
#  'commission',
#  'senior',
#  'council',
#  'board',
#  'advisory',
#  'department',
#  'trade',
#  'industry',
#  'fraud',
#  'senior',
#  'senior',
#  'vision',
#  'elderly',
#  'functional',
#  'visual',
#  'third',
#  'day',
#  'remembrance',
#  'road',
#  'traffic',
#  'legal',
#  'residency',
#  'status',
#  'certain',
#  'certain',
#  'special',
#  'economic',
#  'zone',
#  'area',
#  'villa',
#  'province',
#  'authority',
#  'area',
#  'study',
#  'demonstration',
#  'hepatitis',
#  'c',
#  'emergency',
#  'response',
#  'grant',
#  'fee',
#  'proper',
#  'development',
#  'infrastructure',
#  'quality',
#  'bottled',
#  'water',
#  'palliative',
#  'hospice',
#  'care',
#  'health',
#  'care',
#  'system',
#  'sustainable',
#  'consumer',
#  'electoral',
#  'mandatory',
#  'fair',
#  'election',
#  'safety',
#  'education',
#  'curriculum',
#  'elementary',
#  'teller',
#  'importation',
#  'solid',
#  'waste',
#  'computer',
#  'science',
#  'curriculum',
#  'enhanced',
#  'basic',
#  'education',
#  'social',
#  'pension',
#  'senior',
#  'coverage',
#  'senior',
#  'measurement',
#  'system',
#  'compensation',
#  'reform',
#  'commission',
#  'universal',
#  'social',
#  'pension',
#  'senior',
#  'old',
#  'energy',
#  'regulatory',
#  'framework',
#  'electric',
#  'hybrid',
#  'establishment',
#  'electric',
#  'onetime',
#  'condonation',
#  'interest',
#  'favor',
#  'qualified',
#  'local',
#  'water',
#  'local',
#  'water',
#  'administration',
#  'full',
#  'effective',
#  'implementation',
#  'enforcement',
#  'international',
#  'maritime',
#  'absolute',
#  'divorce',
#  'authority',
#  'area',
#  'area',
#  'consolidated',
#  'poverty',
#  'data',
#  'collection',
#  'system',
#  'polytechnic',
#  'college',
#  'state',
#  'college',
#  'polytechnic',
#  'state',
#  'college',
#  'prison',
#  'reform',
#  'restorative',
#  'justice',
#  'correctional',
#  'system',
#  'franchise',
#  'development',
#  'corporation',
#  'network',
#  'development',
#  'corporation',
#  'business',
#  'name',
#  'company',
#  'franchise',
#  'install',
#  'operate',
#  'maintain',
#  'radio',
#  'television',
#  'hospital',
#  'coast',
#  'guard',
#  'coast',
#  'guard',
#  'general',
#  'hospital',
#  'gross',
#  'international',
#  'internal',
#  'revenue',
#  'indication',
#  'perishable',
#  'agricultural',
#  'country',
#  'origin',
#  'nutritional',
#  'awareness',
#  'nutritional',
#  'content',
#  'information',
#  'food',
#  'number',
#  'charter',
#  'polytechnic',
#  'university',
#  'cost',
#  'business',
#  'local',
#  'certain',
#  'book',
#  'local',
#  'credit',
#  'local',
#  'certain',
#  'book',
#  'local',
#  'poor',
#  'economic',
#  'development',
#  'authority',
#  'independent',
#  'economic',
#  'agency',
#  'series',
#  'rural',
#  'employment',
#  'assistance',
#  'child',
#  'development',
#  'professional',
#  'development',
#  'special',
#  'economic',
#  'zone',
#  'free',
#  'port',
#  'province',
#  'occidental',
#  'public',
#  'private',
#  'educational',
#  'appropriate',
#  'development',
#  'defense',
#  'industry',
#  'strengthening',
#  'self',
#  'reliant',
#  'defense',
#  'posture',
#  'defense',
#  'acquisition',
#  'undersecretary',
#  'defense',
#  'technology',
#  'research',
#  'industry',
#  'development',
#  'department',
#  'defense',
#  'medical',
#  'insurance',
#  'income',
#  'tax',
#  'fringe',
#  'benefit',
#  'tax',
#  'internal',
#  'revenue',
#  'public',
#  'violation',
#  'solicitation',
#  'permit',
#  'grant',
#  'professional',
#  'installation',
#  'fire',
#  'alarm',
#  'detection',
#  'fire',
#  'detection',
#  'prevention',
#  'long',
#  'term',
#  'care',
#  'intellectual',
#  'property',
#  'commission',
#  'service',
#  'infringement',
#  'copyright',
#  'growth',
#  'development',
#  'social',
#  'poverty',
#  'poverty',
#  'reduction',
#  'social',
#  'entrepreneurship',
#  'present',
#  'internal',
#  'revenue',
#  'unified',
#  'housing',
#  'urban',
#  'development',
#  'home',
#  'comprehensive',
#  'shelter',
#  'regulation',
#  'organization',
#  'automatic',
#  'reversal',
#  'excise',
#  'tax',
#  'fuel',
#  'tax',
#  'reform',
#  'acceleration',
#  'inclusion',
#  'train',
#  'internal',
#  'revenue',
#  'industry',
#  'subsidy',
#  'research',
#  'development',
#  'center',
#  'province',
#  'capital',
#  'foreign',
#  'business',
#  'buy',
#  'build',
#  'public',
#  'private',
#  'purchase',
#  'utilization',
#  'creation',
#  'council',
#  'welfare',
#  'senior',
#  'continuous',
#  'uninterrupted',
#  'transmission',
#  'distribution',
#  'electricity',
#  'protection',
#  'integrity',
#  'reliability',
#  'power',
#  'system',
#  'organ',
#  'donation',
#  'transplantation',
#  'organ',
#  'donation',
#  'right',
#  'health',
#  'health',
#  'coverage',
#  'treatment',
#  'breast',
#  'cancer',
#  'minimum',
#  'hospital',
#  'stay',
#  'lymph',
#  'node',
#  'dissection',
#  'coverage',
#  'province',
#  'component',
#  'city',
#  'city',
#  'professional',
#  'development',
#  'local',
#  'housing',
#  'first',
#  'third',
#  'class',
#  'approach',
#  'delivery',
#  'shelter',
#  'support',
#  'informal',
#  'certain',
#  'province',
#  'abaca',
#  'capital',
#  'special',
#  'nonworking',
#  'holiday',
#  'city',
#  'health',
#  'care',
#  'resistant',
#  'establishment',
#  'testing',
#  'evaluation',
#  'strategic',
#  'performance',
#  'measurement',
#  'new',
#  'building',
#  'regulation',
#  'health',
#  'hospital',
#  'licensure',
#  'consumer',
#  'product',
#  'safety',
#  'standard',
#  'durable',
#  'infant',
#  'toddler',
#  'product',
#  'medical',
#  'parole',
#  'grant',
#  'health',
#  'safety',
#  'garbage',
#  'collection',
#  'disaster',
#  'amnesty',
#  'rectification',
#  'birth',
#  'administrative',
#  'adoption',
#  'franchise',
#  'catholic',
#  'conference',
#  'catholic',
#  'welfare',
#  'organization',
#  'install',
#  'operate',
#  'maintain',
#  'radio',
#  'television',
#  'retinoblastoma',
#  'public',
#  'awareness',
#  'prevention',
#  'comprehensive',
#  'substance',
#  'educational',
#  'school',
#  'treatment',
#  'technology',
#  'hazardous',
#  'clean',
#  'air',
#  'special',
#  'economic',
#  'zone',
#  'free',
#  'port',
#  'province',
#  'commission',
#  'urban',
#  'poor',
#  'professional',
#  'development',
#  'synchronized',
#  'local',
#  'electoral',
#  'immigration',
#  'health',
#  'systemic',
#  'lupus',
#  'disease',
#  'comprehensive',
#  'nursing',
#  'towards',
#  'quality',
#  'health',
#  'system',
#  'nursing',
#  'public',
#  'pet',
#  'food',
#  'land',
#  'transportation',
#  'satellite',
#  'province',
#  'district',
#  'branch',
#  'land',
#  'transportation',
#  'judiciary',
#  'reorganization',
#  'strengthening',
#  'development',
#  'authority',
#  'development',
#  'authority',
#  'bed',
#  'capacity',
#  'mental',
#  'hospital',
#  'hundred',
#  'operation',
#  'level',
#  'general',
#  'ward',
#  'bed',
#  'capacity',
#  'mental',
#  'wellness',
#  'general',
#  'hospital',
#  'high',
#  'school',
#  'new',
#  'high',
#  'school',
#  'annex',
#  'barangay',
#  'province',
#  'high',
#  'school',
#  'high',
#  'school',
#  'revenue',
#  'administration',
#  'collection',
#  'tax',
#  'base',
#  'amnesty',
#  'unpaid',
#  'internal',
#  'revenue',
#  'taxable',
#  'prior',
#  'respect',
#  'estate',
#  'tax',
#  'internal',
#  'revenue',
#  'tax',
#  'border',
#  'tax',
#  'evasion',
#  'day',
#  'compensation',
#  'structure',
#  'system',
#  'support',
#  'basic',
#  'education',
#  'teacher',
#  'education',
#  'assistance',
#  'equitable',
#  'transition',
#  'public',
#  'utility',
#  'vehicle',
#  'modernization',
#  'transitory',
#  'assistance',
#  'bed',
#  'capacity',
#  'medical',
#  'center',
#  'city',
#  'professional',
#  'health',
#  'care',
#  'increase',
#  'medical',
#  'personnel',
#  'specialty',
#  'hospital',
#  'city',
#  'province',
#  'maternity',
#  'hospital',
#  'n',
#  'memorial',
#  'hospital',
#  'city',
#  'fourth',
#  'district',
#  'province',
#  'research',
#  'development',
#  'council',
#  'essential',
#  'component',
#  'responsible',
#  'parenthood',
#  ...]

# %%
from collections import Counter

# %%
word_counter = Counter(flat_list)
most_common_words = word_counter.most_common()[:10]
most_common_words
# Out:
# [('public', 1243),
#  ('development', 997),
#  ('health', 919),
#  ('education', 899),
#  ('local', 852),
#  ('system', 749),
#  ('certain', 676),
#  ('school', 611),
#  ('service', 558),
#  ('special', 530)]

# %%
from gensim import matutils, models
import scipy.sparse

# %%
# data_dtm.head()

# %%
# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
# sparse_counts = scipy.sparse.csr_matrix(data_dtm)
# corpus = matutils.Sparse2Corpus(sparse_counts)

# %%
import pickle

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
# tfidfv = pickle.load(open("tfidf.pkl", "rb"))
# id2word = dict((v, k) for k, v in tfidfv.vocabulary_.items())

# %%
# id2word

# %%
df_lemmatized = pd.read_pickle('df_lemma.pkl')

# %%
df_lemmatized.head()
# Out:
#       bill_id                                         long_title bill_status
# 0  17SBN-2235                 [fiscal, regime, mining, industry]     Pending
# 1  17SBN-2234  [sale, certain, land, barangay, city, universi...      Passed
# 2  17SBN-2233  [excise, tax, tobacco, tax, incremental, tobac...      Passed
# 3  17SBN-2232  [institutionalization, development, training, ...     Pending
# 4  17SBN-2231                                             [bank]     Pending

# %%
from gensim import corpora
# Create Dictionary
id2word = corpora.Dictionary(df_lemmatized.long_title)

# Create Corpus
texts = df_lemmatized.long_title

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
# LDA for num_topics = 15
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=10, passes=10, random_state=43)
lda.print_topics()
# Out:
# [(0,
#   '0.047*"system" + 0.031*"education" + 0.030*"technology" + 0.023*"land" + 0.021*"care" + 0.020*"science" + 0.020*"agricultural" + 0.020*"insurance" + 0.019*"assistance" + 0.017*"administration"'),
#  (1,
#   '0.054*"labor" + 0.046*"family" + 0.034*"civil" + 0.020*"personnel" + 0.019*"book" + 0.019*"child" + 0.019*"retirement" + 0.018*"military" + 0.018*"protection" + 0.015*"compensation"'),
#  (2,
#   '0.082*"school" + 0.057*"public" + 0.045*"education" + 0.039*"high" + 0.031*"province" + 0.021*"elementary" + 0.021*"special" + 0.019*"safety" + 0.016*"area" + 0.015*"private"'),
#  (3,
#   '0.052*"tax" + 0.041*"revenue" + 0.040*"internal" + 0.034*"information" + 0.028*"public" + 0.028*"research" + 0.022*"right" + 0.020*"income" + 0.018*"prevention" + 0.015*"credit"'),
#  (4,
#   '0.055*"commission" + 0.045*"security" + 0.035*"protection" + 0.033*"social" + 0.021*"violation" + 0.018*"day" + 0.018*"human" + 0.018*"environmental" + 0.015*"system" + 0.014*"bank"'),
#  (5,
#   '0.032*"employment" + 0.029*"public" + 0.022*"center" + 0.022*"overseas" + 0.014*"management" + 0.014*"department" + 0.014*"student" + 0.013*"sport" + 0.013*"protection" + 0.012*"promotion"'),
#  (6,
#   '0.092*"health" + 0.085*"local" + 0.035*"barangay" + 0.023*"education" + 0.022*"department" + 0.020*"election" + 0.017*"care" + 0.015*"youth" + 0.014*"housing" + 0.014*"development"'),
#  (7,
#   '0.047*"additional" + 0.035*"court" + 0.034*"city" + 0.034*"region" + 0.033*"state" + 0.033*"judiciary" + 0.032*"crime" + 0.031*"reorganization" + 0.028*"trial" + 0.028*"regional"'),
#  (8,
#   '0.076*"development" + 0.056*"authority" + 0.023*"sale" + 0.021*"bureau" + 0.021*"international" + 0.020*"medium" + 0.018*"small" + 0.018*"distribution" + 0.017*"police" + 0.016*"management"'),
#  (9,
#   '0.035*"service" + 0.031*"food" + 0.025*"industry" + 0.025*"welfare" + 0.024*"medical" + 0.022*"certain" + 0.019*"development" + 0.017*"payment" + 0.016*"public" + 0.016*"board"')]

# %%
lda.show_topics()
# Out:
# [(0,
#   '0.047*"system" + 0.031*"education" + 0.030*"technology" + 0.023*"land" + 0.021*"care" + 0.020*"science" + 0.020*"agricultural" + 0.020*"insurance" + 0.019*"assistance" + 0.017*"administration"'),
#  (1,
#   '0.054*"labor" + 0.046*"family" + 0.034*"civil" + 0.020*"personnel" + 0.019*"book" + 0.019*"child" + 0.019*"retirement" + 0.018*"military" + 0.018*"protection" + 0.015*"compensation"'),
#  (2,
#   '0.082*"school" + 0.057*"public" + 0.045*"education" + 0.039*"high" + 0.031*"province" + 0.021*"elementary" + 0.021*"special" + 0.019*"safety" + 0.016*"area" + 0.015*"private"'),
#  (3,
#   '0.052*"tax" + 0.041*"revenue" + 0.040*"internal" + 0.034*"information" + 0.028*"public" + 0.028*"research" + 0.022*"right" + 0.020*"income" + 0.018*"prevention" + 0.015*"credit"'),
#  (4,
#   '0.055*"commission" + 0.045*"security" + 0.035*"protection" + 0.033*"social" + 0.021*"violation" + 0.018*"day" + 0.018*"human" + 0.018*"environmental" + 0.015*"system" + 0.014*"bank"'),
#  (5,
#   '0.032*"employment" + 0.029*"public" + 0.022*"center" + 0.022*"overseas" + 0.014*"management" + 0.014*"department" + 0.014*"student" + 0.013*"sport" + 0.013*"protection" + 0.012*"promotion"'),
#  (6,
#   '0.092*"health" + 0.085*"local" + 0.035*"barangay" + 0.023*"education" + 0.022*"department" + 0.020*"election" + 0.017*"care" + 0.015*"youth" + 0.014*"housing" + 0.014*"development"'),
#  (7,
#   '0.047*"additional" + 0.035*"court" + 0.034*"city" + 0.034*"region" + 0.033*"state" + 0.033*"judiciary" + 0.032*"crime" + 0.031*"reorganization" + 0.028*"trial" + 0.028*"regional"'),
#  (8,
#   '0.076*"development" + 0.056*"authority" + 0.023*"sale" + 0.021*"bureau" + 0.021*"international" + 0.020*"medium" + 0.018*"small" + 0.018*"distribution" + 0.017*"police" + 0.016*"management"'),
#  (9,
#   '0.035*"service" + 0.031*"food" + 0.025*"industry" + 0.025*"welfare" + 0.024*"medical" + 0.022*"certain" + 0.019*"development" + 0.017*"payment" + 0.016*"public" + 0.016*"board"')]

# %%
for i in  lda.show_topics():
    print(i[1])
# Out:
# 0.047*"system" + 0.031*"education" + 0.030*"technology" + 0.023*"land" + 0.021*"care" + 0.020*"science" + 0.020*"agricultural" + 0.020*"insurance" + 0.019*"assistance" + 0.017*"administration"
# 0.054*"labor" + 0.046*"family" + 0.034*"civil" + 0.020*"personnel" + 0.019*"book" + 0.019*"child" + 0.019*"retirement" + 0.018*"military" + 0.018*"protection" + 0.015*"compensation"
# 0.082*"school" + 0.057*"public" + 0.045*"education" + 0.039*"high" + 0.031*"province" + 0.021*"elementary" + 0.021*"special" + 0.019*"safety" + 0.016*"area" + 0.015*"private"
# 0.052*"tax" + 0.041*"revenue" + 0.040*"internal" + 0.034*"information" + 0.028*"public" + 0.028*"research" + 0.022*"right" + 0.020*"income" + 0.018*"prevention" + 0.015*"credit"
# 0.055*"commission" + 0.045*"security" + 0.035*"protection" + 0.033*"social" + 0.021*"violation" + 0.018*"day" + 0.018*"human" + 0.018*"environmental" + 0.015*"system" + 0.014*"bank"
# 0.032*"employment" + 0.029*"public" + 0.022*"center" + 0.022*"overseas" + 0.014*"management" + 0.014*"department" + 0.014*"student" + 0.013*"sport" + 0.013*"protection" + 0.012*"promotion"
# 0.092*"health" + 0.085*"local" + 0.035*"barangay" + 0.023*"education" + 0.022*"department" + 0.020*"election" + 0.017*"care" + 0.015*"youth" + 0.014*"housing" + 0.014*"development"
# 0.047*"additional" + 0.035*"court" + 0.034*"city" + 0.034*"region" + 0.033*"state" + 0.033*"judiciary" + 0.032*"crime" + 0.031*"reorganization" + 0.028*"trial" + 0.028*"regional"
# 0.076*"development" + 0.056*"authority" + 0.023*"sale" + 0.021*"bureau" + 0.021*"international" + 0.020*"medium" + 0.018*"small" + 0.018*"distribution" + 0.017*"police" + 0.016*"management"
# 0.035*"service" + 0.031*"food" + 0.025*"industry" + 0.025*"welfare" + 0.024*"medical" + 0.022*"certain" + 0.019*"development" + 0.017*"payment" + 0.016*"public" + 0.016*"board"

# %%
import re
topic_model = {}
for idx, i in enumerate(lda.show_topics()):
    topic_model[idx] = re.findall('"([^"]*)"', i[1])

# %%
topic_model
# Out:
# {0: ['system',
#   'education',
#   'technology',
#   'land',
#   'care',
#   'science',
#   'agricultural',
#   'insurance',
#   'assistance',
#   'administration'],
#  1: ['labor',
#   'family',
#   'civil',
#   'personnel',
#   'book',
#   'child',
#   'retirement',
#   'military',
#   'protection',
#   'compensation'],
#  2: ['school',
#   'public',
#   'education',
#   'high',
#   'province',
#   'elementary',
#   'special',
#   'safety',
#   'area',
#   'private'],
#  3: ['tax',
#   'revenue',
#   'internal',
#   'information',
#   'public',
#   'research',
#   'right',
#   'income',
#   'prevention',
#   'credit'],
#  4: ['commission',
#   'security',
#   'protection',
#   'social',
#   'violation',
#   'day',
#   'human',
#   'environmental',
#   'system',
#   'bank'],
#  5: ['employment',
#   'public',
#   'center',
#   'overseas',
#   'management',
#   'department',
#   'student',
#   'sport',
#   'protection',
#   'promotion'],
#  6: ['health',
#   'local',
#   'barangay',
#   'education',
#   'department',
#   'election',
#   'care',
#   'youth',
#   'housing',
#   'development'],
#  7: ['additional',
#   'court',
#   'city',
#   'region',
#   'state',
#   'judiciary',
#   'crime',
#   'reorganization',
#   'trial',
#   'regional'],
#  8: ['development',
#   'authority',
#   'sale',
#   'bureau',
#   'international',
#   'medium',
#   'small',
#   'distribution',
#   'police',
#   'management'],
#  9: ['service',
#   'food',
#   'industry',
#   'welfare',
#   'medical',
#   'certain',
#   'development',
#   'payment',
#   'public',
#   'board']}

# %%
import pickle
pickle.dump(topic_model, open("topic_models.pkl", "wb"))

# %%
from gensim.models import CoherenceModel

# %%
# Compute Perplexity
print('\nPerplexity: ', lda.log_perplexity(corpus))  

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda, texts=df_lemmatized.long_title, dictionary=id2word, coherence='c_v')

# %%
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

# %%
import pyLDAvis
import pyLDAvis.gensim  # don't skip this

# %%
# Visualize the topics
pyLDAvis.enable_notebook()

# %%
vis = pyLDAvis.gensim.prepare(lda, corpus, id2word)
vis

# %%
# pyLDAvis_01.save_html(vis, 'lda_75_lem_5_pass.html')
