# %% [markdown]
# # Text Processing – Long Titles from Philippines Senate Bills

# %%
# Hide Warning messages
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Setting Up Pandas Options

# %%
# For loading, manipulating dataframe.
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Loading the Data

# %%
df_congress = pd.read_csv('congress_data_set.csv',index_col=0)
print(f"df_congress has {df_congress.shape[0]:,} rows by {df_congress.shape[1]} columns.")
df_congress.head(1)
# Out:
# df_congress has 15,078 rows by 22 columns.
#       bill_id       num  congress  \
# 0  17SBN-2235  SBN-2235  17
#
#                                                       long_title  date_filed  \
# 0  an act establishing the fiscal regime for the mining industry  2019-05-28
#
#       scope                                 status  \
# 0  National  Pending Second Reading, Special Order
#
#                                                                                          author  \
# 0  Drilon, Franklin M., Recto, Ralph G., Sotto III, Vicente C., Angara, Juan Edgardo "Sonny" M.
#
#   date_lastUpdate  passed Full Name Primary Author    Party      Bloc  \
# 0  2019-05-28      False   Franklin Drilon          Liberal  Minority
#
#    Years of Service  num_authors  delta_days  upper  mon  quarter  \
# 0  24.0              4            0.0         False  5    2.0
#
#    scope_national  majority_bloc  len_desc
# 0  True            False          61

# %%
df_congress['bill_status'] = np.where(df_congress.passed==True,"Passed",
                                     np.where(df_congress.status=='Sent to the Archives',"Archived","Pending")
                                     )

# %%
df_congress.bill_status.value_counts(dropna=False)
# Out:
# Pending     14549
# Passed      438
# Archived    91
# Name: bill_status, dtype: int64

# %% [markdown]
# ## Cleaning Data

# %%
df_billText = df_congress[['bill_id','long_title', 'bill_status']]
df_billText.head(20)
# Out:
#        bill_id  \
# 0   17SBN-2235
# 1   17SBN-2234
# 2   17SBN-2233
# 3   17SBN-2232
# 4   17SBN-2231
# 5   17SBN-2230
# 6   17SBN-2229
# 7   17SBN-2228
# 8   17SBN-2227
# 9   17SBN-2226
# 10  17SBN-2225
# 11  17SBN-2224
# 12  17SBN-2223
# 13  17SBN-2222
# 14  17SBN-2221
# 15  17SBN-2220
# 16  17SBN-2219
# 17  17SBN-2218
# 18  17SBN-2217
# 19  17SBN-2216
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        long_title  \
# 0   an act establishing the fiscal regime for the mining industry
# 1   an act authorizing the sale of certain parcels of land in barangay krus na ligas, quezon city by the university of the philippines to the quezon city government amending for the purpose republic act no. 9500, otherwise known as the university of the philippines charter of 2008 and for other purposes
# 2   an act increasing the excise tax on tobacco products, the penalties for violations of provisions on articles subject to excise tax, and earmarking incremental tobacco excise tax for human resource development programs for health professionals, amending for this purpose sections 145, 164, 260, 262, 263, 265 and 288(c) of the national internal revenue code of 1997, as amended by republic act no. 10963, and for other purposes
# 3   an act mandating the institutionalization, development, training, organization and administration of basic reserve officers training corps (rotc) in grades 11 and 12 in public and private educational institutions, further amending republic act no. 7077 , otherwise known as the  citizen armed force or armed forces of the philippines reservist act , as amended by republic act no. 9163 , otherwise known as the national service training program and appropriating funds therefor
# 4   an act strengthening the al-amanah islamic bank
# 5   an act designating the 3rd sunday of november annually as the philippine day of remembrance for road crash victims, survivors and families
# 6   an act designating the third sunday of november as the philippine day of remembrance for road crash victims, survivors and families
# 7   an act declaring the balanga wetland and nature park located in barangay tortugas, city of balanga, province of bataan as a responsible, community-based ecotourism zone and appropriating funds therefor
# 8   an act amending republic act no. 7042, otherwise known as the foreign investments act of 1991, as amended by republic act no. 8179, and for other purposes
# 9   an act allowing disclosure of deposits, repealing for the purpose the pertinent laws on secrecy of deposits
# 10  an act establishing a national evaluation policy
# 11  an act protecting children by prohibiting and declaring child marriage as illegal, and imposing penalties thereof
# 12  an act further amending republic act no. 8182, as amended by republic act no. 8555, and for other purposes
# 13  an act creating the energy consumer advocate office, providing funds therefor, and for other purposes
# 14  an act establishing the marinduque sports academy and training center in barangay baliis, municipality of sta. cruz in the province of marinduque
# 15  an act exempting all vehicles from paying toll fees on certain holidays, amending for the purpose presidential decree no. 1112, as amended
# 16  an act institutionalizing the participation of civil society organizations (csos) in the preparation and authorization process of the annual national budget, providing effective mechanisms therefor, and for other purposes
# 17  an act amending promoting the use of microgrid systems for the total electrification of unserved and underserved areas
# 18  an act renaming the veterans memorial medical (vmmc) center located in diliman, quezon city to veterans medical center (vmc)
# 19  an act creating the department of water, irrigation, sewage and sanitation resource management, defining its powers and functions, appropriating funds therefor, and for other purposes
#
#    bill_status
# 0   Pending
# 1   Passed
# 2   Passed
# 3   Pending
# 4   Pending
# 5   Pending
# 6   Pending
# 7   Passed
# 8   Pending
# 9   Pending
# 10  Pending
# 11  Pending
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18  Pending
# 19  Pending

# %% [markdown]
# ### Punctuations and Numbers Removal

# %%
import re, string

# %%
def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text
round1 = lambda x: clean_text_round1(x)

# %%
# Let's take a look at the updated text
df_billText['long_title'] = df_billText.long_title.apply(round1)
df_billText.head(20)
# Out:
#        bill_id  \
# 0   17SBN-2235
# 1   17SBN-2234
# 2   17SBN-2233
# 3   17SBN-2232
# 4   17SBN-2231
# 5   17SBN-2230
# 6   17SBN-2229
# 7   17SBN-2228
# 8   17SBN-2227
# 9   17SBN-2226
# 10  17SBN-2225
# 11  17SBN-2224
# 12  17SBN-2223
# 13  17SBN-2222
# 14  17SBN-2221
# 15  17SBN-2220
# 16  17SBN-2219
# 17  17SBN-2218
# 18  17SBN-2217
# 19  17SBN-2216
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 long_title  \
# 0   an act establishing the fiscal regime for the mining industry
# 1   an act authorizing the sale of certain parcels of land in barangay krus na ligas quezon city by the university of the philippines to the quezon city government amending for the purpose republic act no  otherwise known as the university of the philippines charter of  and for other purposes
# 2   an act increasing the excise tax on tobacco products the penalties for violations of provisions on articles subject to excise tax and earmarking incremental tobacco excise tax for human resource development programs for health professionals amending for this purpose sections       and  of the national internal revenue code of  as amended by republic act no  and for other purposes
# 3   an act mandating the institutionalization development training organization and administration of basic reserve officers training corps rotc in grades  and  in public and private educational institutions further amending republic act no   otherwise known as the  citizen armed force or armed forces of the philippines reservist act  as amended by republic act no   otherwise known as the national service training program and appropriating funds therefor
# 4   an act strengthening the alamanah islamic bank
# 5   an act designating the  sunday of november annually as the philippine day of remembrance for road crash victims survivors and families
# 6   an act designating the third sunday of november as the philippine day of remembrance for road crash victims survivors and families
# 7   an act declaring the balanga wetland and nature park located in barangay tortugas city of balanga province of bataan as a responsible communitybased ecotourism zone and appropriating funds therefor
# 8   an act amending republic act no  otherwise known as the foreign investments act of  as amended by republic act no  and for other purposes
# 9   an act allowing disclosure of deposits repealing for the purpose the pertinent laws on secrecy of deposits
# 10  an act establishing a national evaluation policy
# 11  an act protecting children by prohibiting and declaring child marriage as illegal and imposing penalties thereof
# 12  an act further amending republic act no  as amended by republic act no  and for other purposes
# 13  an act creating the energy consumer advocate office providing funds therefor and for other purposes
# 14  an act establishing the marinduque sports academy and training center in barangay baliis municipality of sta cruz in the province of marinduque
# 15  an act exempting all vehicles from paying toll fees on certain holidays amending for the purpose presidential decree no  as amended
# 16  an act institutionalizing the participation of civil society organizations csos in the preparation and authorization process of the annual national budget providing effective mechanisms therefor and for other purposes
# 17  an act amending promoting the use of microgrid systems for the total electrification of unserved and underserved areas
# 18  an act renaming the veterans memorial medical vmmc center located in diliman quezon city to veterans medical center vmc
# 19  an act creating the department of water irrigation sewage and sanitation resource management defining its powers and functions appropriating funds therefor and for other purposes
#
#    bill_status
# 0   Pending
# 1   Passed
# 2   Passed
# 3   Pending
# 4   Pending
# 5   Pending
# 6   Pending
# 7   Passed
# 8   Pending
# 9   Pending
# 10  Pending
# 11  Pending
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18  Pending
# 19  Pending

# %%
df_billText.to_pickle("clean_billtext.pkl")

# %% [markdown]
# ### Tokenization of Words

# %%
# Text Preprocessing
from nltk import word_tokenize

# %%
df_billText['long_title'] = df_billText.long_title.map(word_tokenize)
df_billText.head(10)
# Out:
#       bill_id  \
# 0  17SBN-2235
# 1  17SBN-2234
# 2  17SBN-2233
# 3  17SBN-2232
# 4  17SBN-2231
# 5  17SBN-2230
# 6  17SBN-2229
# 7  17SBN-2228
# 8  17SBN-2227
# 9  17SBN-2226
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         long_title  \
# 0  [an, act, establishing, the, fiscal, regime, for, the, mining, industry]
# 1  [an, act, authorizing, the, sale, of, certain, parcels, of, land, in, barangay, krus, na, ligas, quezon, city, by, the, university, of, the, philippines, to, the, quezon, city, government, amending, for, the, purpose, republic, act, no, otherwise, known, as, the, university, of, the, philippines, charter, of, and, for, other, purposes]
# 2  [an, act, increasing, the, excise, tax, on, tobacco, products, the, penalties, for, violations, of, provisions, on, articles, subject, to, excise, tax, and, earmarking, incremental, tobacco, excise, tax, for, human, resource, development, programs, for, health, professionals, amending, for, this, purpose, sections, and, of, the, national, internal, revenue, code, of, as, amended, by, republic, act, no, and, for, other, purposes]
# 3  [an, act, mandating, the, institutionalization, development, training, organization, and, administration, of, basic, reserve, officers, training, corps, rotc, in, grades, and, in, public, and, private, educational, institutions, further, amending, republic, act, no, otherwise, known, as, the, citizen, armed, force, or, armed, forces, of, the, philippines, reservist, act, as, amended, by, republic, act, no, otherwise, known, as, the, national, service, training, program, and, appropriating, funds, therefor]
# 4  [an, act, strengthening, the, alamanah, islamic, bank]
# 5  [an, act, designating, the, sunday, of, november, annually, as, the, philippine, day, of, remembrance, for, road, crash, victims, survivors, and, families]
# 6  [an, act, designating, the, third, sunday, of, november, as, the, philippine, day, of, remembrance, for, road, crash, victims, survivors, and, families]
# 7  [an, act, declaring, the, balanga, wetland, and, nature, park, located, in, barangay, tortugas, city, of, balanga, province, of, bataan, as, a, responsible, communitybased, ecotourism, zone, and, appropriating, funds, therefor]
# 8  [an, act, amending, republic, act, no, otherwise, known, as, the, foreign, investments, act, of, as, amended, by, republic, act, no, and, for, other, purposes]
# 9  [an, act, allowing, disclosure, of, deposits, repealing, for, the, purpose, the, pertinent, laws, on, secrecy, of, deposits]
#
#   bill_status
# 0  Pending
# 1  Passed
# 2  Passed
# 3  Pending
# 4  Pending
# 5  Pending
# 6  Pending
# 7  Passed
# 8  Pending
# 9  Pending

# %% [markdown]
# ### Removal of Non-English Words

# %%
import nltk

# %%
eng_words = set(nltk.corpus.words.words())
df_billText['long_title'] = df_billText.long_title.map(lambda words: [word for word in words if word in eng_words])
df_billText.head(20)
# Out:
#        bill_id  \
# 0   17SBN-2235
# 1   17SBN-2234
# 2   17SBN-2233
# 3   17SBN-2232
# 4   17SBN-2231
# 5   17SBN-2230
# 6   17SBN-2229
# 7   17SBN-2228
# 8   17SBN-2227
# 9   17SBN-2226
# 10  17SBN-2225
# 11  17SBN-2224
# 12  17SBN-2223
# 13  17SBN-2222
# 14  17SBN-2221
# 15  17SBN-2220
# 16  17SBN-2219
# 17  17SBN-2218
# 18  17SBN-2217
# 19  17SBN-2216
#
#                                                                                                                                                                                                                                                                                                                                                                                                                  long_title  \
# 0   [an, act, the, fiscal, regime, for, the, mining, industry]
# 1   [an, act, the, sale, of, certain, of, land, in, barangay, na, ligas, city, by, the, university, of, the, to, the, city, government, for, the, purpose, republic, act, no, otherwise, known, as, the, university, of, the, charter, of, and, for, other]
# 2   [an, act, increasing, the, excise, tax, on, tobacco, the, for, of, on, subject, to, excise, tax, and, incremental, tobacco, excise, tax, for, human, resource, development, for, health, for, this, purpose, and, of, the, national, internal, revenue, code, of, as, by, republic, act, no, and, for, other]
# 3   [an, act, the, institutionalization, development, training, organization, and, administration, of, basic, reserve, training, corps, in, and, in, public, and, private, educational, further, republic, act, no, otherwise, known, as, the, citizen, armed, force, or, armed, of, the, reservist, act, as, by, republic, act, no, otherwise, known, as, the, national, service, training, program, and, funds, therefor]
# 4   [an, act, strengthening, the, bank]
# 5   [an, act, the, of, annually, as, the, day, of, remembrance, for, road, crash, and]
# 6   [an, act, the, third, of, as, the, day, of, remembrance, for, road, crash, and]
# 7   [an, act, the, and, nature, park, in, barangay, city, of, province, of, bataan, as, a, responsible, zone, and, funds, therefor]
# 8   [an, act, republic, act, no, otherwise, known, as, the, foreign, act, of, as, by, republic, act, no, and, for, other]
# 9   [an, act, disclosure, of, for, the, purpose, the, pertinent, on, secrecy, of]
# 10  [an, act, a, national, evaluation, policy]
# 11  [an, act, protecting, by, and, child, marriage, as, illegal, and, imposing, thereof]
# 12  [an, act, further, republic, act, no, as, by, republic, act, no, and, for, other]
# 13  [an, act, the, energy, consumer, advocate, office, providing, funds, therefor, and, for, other]
# 14  [an, act, the, sports, academy, and, training, center, in, barangay, municipality, of, in, the, province, of]
# 15  [an, act, all, from, paying, toll, on, certain, for, the, purpose, presidential, decree, no, as]
# 16  [an, act, the, participation, of, civil, society, in, the, preparation, and, authorization, process, of, the, annual, national, budget, providing, effective, therefor, and, for, other]
# 17  [an, act, the, use, of, for, the, total, electrification, of, unserved, and]
# 18  [an, act, the, memorial, medical, center, in, city, to, medical, center]
# 19  [an, act, the, department, of, water, irrigation, sewage, and, sanitation, resource, management, its, and, funds, therefor, and, for, other]
#
#    bill_status
# 0   Pending
# 1   Passed
# 2   Passed
# 3   Pending
# 4   Pending
# 5   Pending
# 6   Pending
# 7   Passed
# 8   Pending
# 9   Pending
# 10  Pending
# 11  Pending
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18  Pending
# 19  Pending

# %% [markdown]
# ### Word Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
df_billText['long_title'] = df_billText.long_title.map(lambda words: 
                                                                [lemmatizer.lemmatize(word) for word in words])
df_billText.head(20)
# Out:
#        bill_id  \
# 0   17SBN-2235
# 1   17SBN-2234
# 2   17SBN-2233
# 3   17SBN-2232
# 4   17SBN-2231
# 5   17SBN-2230
# 6   17SBN-2229
# 7   17SBN-2228
# 8   17SBN-2227
# 9   17SBN-2226
# 10  17SBN-2225
# 11  17SBN-2224
# 12  17SBN-2223
# 13  17SBN-2222
# 14  17SBN-2221
# 15  17SBN-2220
# 16  17SBN-2219
# 17  17SBN-2218
# 18  17SBN-2217
# 19  17SBN-2216
#
#                                                                                                                                                                                                                                                                                                                                                                                                             long_title  \
# 0   [an, act, the, fiscal, regime, for, the, mining, industry]
# 1   [an, act, the, sale, of, certain, of, land, in, barangay, na, ligas, city, by, the, university, of, the, to, the, city, government, for, the, purpose, republic, act, no, otherwise, known, a, the, university, of, the, charter, of, and, for, other]
# 2   [an, act, increasing, the, excise, tax, on, tobacco, the, for, of, on, subject, to, excise, tax, and, incremental, tobacco, excise, tax, for, human, resource, development, for, health, for, this, purpose, and, of, the, national, internal, revenue, code, of, a, by, republic, act, no, and, for, other]
# 3   [an, act, the, institutionalization, development, training, organization, and, administration, of, basic, reserve, training, corp, in, and, in, public, and, private, educational, further, republic, act, no, otherwise, known, a, the, citizen, armed, force, or, armed, of, the, reservist, act, a, by, republic, act, no, otherwise, known, a, the, national, service, training, program, and, fund, therefor]
# 4   [an, act, strengthening, the, bank]
# 5   [an, act, the, of, annually, a, the, day, of, remembrance, for, road, crash, and]
# 6   [an, act, the, third, of, a, the, day, of, remembrance, for, road, crash, and]
# 7   [an, act, the, and, nature, park, in, barangay, city, of, province, of, bataan, a, a, responsible, zone, and, fund, therefor]
# 8   [an, act, republic, act, no, otherwise, known, a, the, foreign, act, of, a, by, republic, act, no, and, for, other]
# 9   [an, act, disclosure, of, for, the, purpose, the, pertinent, on, secrecy, of]
# 10  [an, act, a, national, evaluation, policy]
# 11  [an, act, protecting, by, and, child, marriage, a, illegal, and, imposing, thereof]
# 12  [an, act, further, republic, act, no, a, by, republic, act, no, and, for, other]
# 13  [an, act, the, energy, consumer, advocate, office, providing, fund, therefor, and, for, other]
# 14  [an, act, the, sport, academy, and, training, center, in, barangay, municipality, of, in, the, province, of]
# 15  [an, act, all, from, paying, toll, on, certain, for, the, purpose, presidential, decree, no, a]
# 16  [an, act, the, participation, of, civil, society, in, the, preparation, and, authorization, process, of, the, annual, national, budget, providing, effective, therefor, and, for, other]
# 17  [an, act, the, use, of, for, the, total, electrification, of, unserved, and]
# 18  [an, act, the, memorial, medical, center, in, city, to, medical, center]
# 19  [an, act, the, department, of, water, irrigation, sewage, and, sanitation, resource, management, it, and, fund, therefor, and, for, other]
#
#    bill_status
# 0   Pending
# 1   Passed
# 2   Passed
# 3   Pending
# 4   Pending
# 5   Pending
# 6   Pending
# 7   Passed
# 8   Pending
# 9   Pending
# 10  Pending
# 11  Pending
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18  Pending
# 19  Pending

# %% [markdown]
# ### Part of Speech Tagging

# %%
from nltk import pos_tag

# %%
df_billText['long_title'] = df_billText.long_title.map(pos_tag)
df_billText['long_title'] = df_billText.long_title.map(lambda words: 
                            [word for word in words if (word[1].startswith(('N','J','R','V')))])
df_billText.head(20)
# Out:
#        bill_id  \
# 0   17SBN-2235
# 1   17SBN-2234
# 2   17SBN-2233
# 3   17SBN-2232
# 4   17SBN-2231
# 5   17SBN-2230
# 6   17SBN-2229
# 7   17SBN-2228
# 8   17SBN-2227
# 9   17SBN-2226
# 10  17SBN-2225
# 11  17SBN-2224
# 12  17SBN-2223
# 13  17SBN-2222
# 14  17SBN-2221
# 15  17SBN-2220
# 16  17SBN-2219
# 17  17SBN-2218
# 18  17SBN-2217
# 19  17SBN-2216
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           long_title  \
# 0   [(act, NN), (fiscal, JJ), (regime, NN), (mining, NN), (industry, NN)]
# 1   [(act, NN), (sale, NN), (certain, JJ), (land, NN), (barangay, NN), (na, JJ), (ligas, NN), (city, NN), (university, NN), (city, NN), (government, NN), (purpose, JJ), (republic, JJ), (act, NN), (otherwise, RB), (known, VBN), (university, NN), (charter, NN), (other, JJ)]
# 2   [(act, NN), (increasing, VBG), (excise, NN), (tax, NN), (tobacco, NN), (subject, NN), (excise, VB), (tax, NN), (incremental, JJ), (tobacco, NN), (excise, NN), (tax, NN), (human, JJ), (resource, NN), (development, NN), (health, NN), (purpose, NN), (national, JJ), (internal, JJ), (revenue, NN), (code, NN), (republic, JJ), (act, NN), (other, JJ)]
# 3   [(act, NN), (institutionalization, NN), (development, NN), (training, NN), (organization, NN), (administration, NN), (basic, JJ), (reserve, NN), (training, VBG), (corp, NN), (public, JJ), (private, JJ), (educational, JJ), (further, RBR), (republic, JJ), (act, NN), (otherwise, RB), (known, VBN), (citizen, NN), (armed, VBD), (force, NN), (armed, VBN), (reservist, NN), (act, NN), (republic, JJ), (act, NN), (otherwise, RB), (known, VBN), (national, JJ), (service, NN), (training, VBG), (program, NN), (fund, NN), (therefor, NN)]
# 4   [(act, NN), (strengthening, VBG), (bank, NN)]
# 5   [(act, NN), (annually, RB), (day, NN), (remembrance, NN), (road, NN), (crash, NN)]
# 6   [(act, NN), (third, JJ), (day, NN), (remembrance, NN), (road, NN), (crash, NN)]
# 7   [(act, NN), (nature, NN), (park, NN), (barangay, JJ), (city, NN), (province, NN), (bataan, NN), (responsible, JJ), (zone, NN), (fund, NN), (therefor, NN)]
# 8   [(act, NN), (republic, JJ), (act, NN), (otherwise, RB), (known, VBN), (foreign, JJ), (act, NN), (republic, JJ), (act, NN), (other, JJ)]
# 9   [(act, JJ), (disclosure, NN), (purpose, NN), (pertinent, NN), (secrecy, NN)]
# 10  [(act, NN), (national, JJ), (evaluation, NN), (policy, NN)]
# 11  [(act, NN), (protecting, NN), (child, JJ), (marriage, NN), (illegal, JJ), (imposing, VBG), (thereof, NN)]
# 12  [(act, NN), (further, RBR), (republic, JJ), (act, NN), (republic, JJ), (act, NN), (other, JJ)]
# 13  [(act, NN), (energy, NN), (consumer, NN), (advocate, NN), (office, NN), (providing, VBG), (fund, NN), (therefor, NN), (other, JJ)]
# 14  [(act, NN), (sport, NN), (academy, NN), (training, NN), (center, NN), (barangay, JJ), (municipality, NN), (province, NN)]
# 15  [(act, NN), (paying, VBG), (toll, NN), (certain, JJ), (purpose, JJ), (presidential, JJ), (decree, NN)]
# 16  [(act, NN), (participation, NN), (civil, JJ), (society, NN), (preparation, NN), (authorization, NN), (process, NN), (annual, JJ), (national, JJ), (budget, NN), (providing, VBG), (effective, JJ), (therefor, NNS), (other, JJ)]
# 17  [(act, NN), (use, NN), (total, JJ), (electrification, NN), (unserved, JJ)]
# 18  [(act, NN), (memorial, JJ), (medical, JJ), (center, NN), (city, NN), (medical, JJ), (center, NN)]
# 19  [(act, NN), (department, NN), (water, NN), (irrigation, NN), (sewage, NN), (sanitation, NN), (resource, NN), (management, NN), (fund, VB), (therefor, NN), (other, JJ)]
#
#    bill_status
# 0   Pending
# 1   Passed
# 2   Passed
# 3   Pending
# 4   Pending
# 5   Pending
# 6   Pending
# 7   Passed
# 8   Pending
# 9   Pending
# 10  Pending
# 11  Pending
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18  Pending
# 19  Pending

# %% [markdown]
# ### Removal of Stop Words

# %%
from nltk.corpus import stopwords

# %%
stoppers = stopwords.words('english')
useless = ['act','presidential','code','government','provide','purpose','therefor','penal','thereof','article',
           'provision','therefore','ra','b','san','sa','decree','fund','program','national','law','republic',
           'otherwise','section','ae','biri','han','hereof','hereon','mandate','met','ni','nineteen','ninety',
           'non','papa','par','para','pia','po','poblacion','pst','pup','purpose','pia','maria','mary','rosario',
           'sangley','sec','second','secondary','secondhand','seventeen','seventeenth','seventh','seventy','si',
           'sixteen','sixteenth','sixth','sora','st','sate','stateless','statement','sub','subject','subparagraph',
           'sur','taft','tala','talisay','tecnology','tecum','therefor','therefrom','thereon','thereto','thereunder',
           'therewith','thing','thirteen','thirteenth','thirty','thousand','ti','title','toa','ton','triangle','tuba',
           'tuber','twelfth','unit','usage','use','used','useful','user','utilize','vice','wanton','whomsoever','year',
           'yearly','yer','yam','wa','unto','unsought','type','tubig','tort','thank','th','tenth','sun','subtitle','solo',
           'set','session','red','rattan','president','presidential','political','policy','plenary','plebiscite','pili',
           'pilar','peter','peso','pedro','pascual','party','panglima','pandan','palay','pablo','ordinance','order','orderly',
           'official','officer','office','oath','nipa','ninth','naga','naa','murphy','municipality','municipal','multiple',
           'mount','mosser','morong','monthly','month','monte','middle','micro','mayor','martin','marikina','march','manila',
           'madrasah','luna','fe','da','ce','bos','bogo','amang','bataan','na','ligas']
stoppers.extend(useless)

# %%
df_billText['long_title']=df_billText.long_title.map(lambda tags:[tag[0] for tag in tags if tag[0] not in stoppers])
df_billText.head(20)
# Out:
#        bill_id  \
# 0   17SBN-2235
# 1   17SBN-2234
# 2   17SBN-2233
# 3   17SBN-2232
# 4   17SBN-2231
# 5   17SBN-2230
# 6   17SBN-2229
# 7   17SBN-2228
# 8   17SBN-2227
# 9   17SBN-2226
# 10  17SBN-2225
# 11  17SBN-2224
# 12  17SBN-2223
# 13  17SBN-2222
# 14  17SBN-2221
# 15  17SBN-2220
# 16  17SBN-2219
# 17  17SBN-2218
# 18  17SBN-2217
# 19  17SBN-2216
#
#                                                                                                                                                                                                              long_title  \
# 0   [fiscal, regime, mining, industry]
# 1   [sale, certain, land, barangay, city, university, city, known, university, charter]
# 2   [increasing, excise, tax, tobacco, excise, tax, incremental, tobacco, excise, tax, human, resource, development, health, internal, revenue]
# 3   [institutionalization, development, training, organization, administration, basic, reserve, training, corp, public, private, educational, known, citizen, armed, force, armed, reservist, known, service, training]
# 4   [strengthening, bank]
# 5   [annually, day, remembrance, road, crash]
# 6   [third, day, remembrance, road, crash]
# 7   [nature, park, barangay, city, province, responsible, zone]
# 8   [known, foreign]
# 9   [disclosure, pertinent, secrecy]
# 10  [evaluation]
# 11  [protecting, child, marriage, illegal, imposing]
# 12  []
# 13  [energy, consumer, advocate, providing]
# 14  [sport, academy, training, center, barangay, province]
# 15  [paying, toll, certain]
# 16  [participation, civil, society, preparation, authorization, process, annual, budget, providing, effective]
# 17  [total, electrification, unserved]
# 18  [memorial, medical, center, city, medical, center]
# 19  [department, water, irrigation, sewage, sanitation, resource, management]
#
#    bill_status
# 0   Pending
# 1   Passed
# 2   Passed
# 3   Pending
# 4   Pending
# 5   Pending
# 6   Pending
# 7   Passed
# 8   Pending
# 9   Pending
# 10  Pending
# 11  Pending
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18  Pending
# 19  Pending

# %%
df_billText.loc[df_billText.long_title.apply(lambda x: len(x))==0,'long_title'] = np.nan
df_billText.head(20)
# Out:
#        bill_id  \
# 0   17SBN-2235
# 1   17SBN-2234
# 2   17SBN-2233
# 3   17SBN-2232
# 4   17SBN-2231
# 5   17SBN-2230
# 6   17SBN-2229
# 7   17SBN-2228
# 8   17SBN-2227
# 9   17SBN-2226
# 10  17SBN-2225
# 11  17SBN-2224
# 12  17SBN-2223
# 13  17SBN-2222
# 14  17SBN-2221
# 15  17SBN-2220
# 16  17SBN-2219
# 17  17SBN-2218
# 18  17SBN-2217
# 19  17SBN-2216
#
#                                                                                                                                                                                                              long_title  \
# 0   [fiscal, regime, mining, industry]
# 1   [sale, certain, land, barangay, city, university, city, known, university, charter]
# 2   [increasing, excise, tax, tobacco, excise, tax, incremental, tobacco, excise, tax, human, resource, development, health, internal, revenue]
# 3   [institutionalization, development, training, organization, administration, basic, reserve, training, corp, public, private, educational, known, citizen, armed, force, armed, reservist, known, service, training]
# 4   [strengthening, bank]
# 5   [annually, day, remembrance, road, crash]
# 6   [third, day, remembrance, road, crash]
# 7   [nature, park, barangay, city, province, responsible, zone]
# 8   [known, foreign]
# 9   [disclosure, pertinent, secrecy]
# 10  [evaluation]
# 11  [protecting, child, marriage, illegal, imposing]
# 12  NaN
# 13  [energy, consumer, advocate, providing]
# 14  [sport, academy, training, center, barangay, province]
# 15  [paying, toll, certain]
# 16  [participation, civil, society, preparation, authorization, process, annual, budget, providing, effective]
# 17  [total, electrification, unserved]
# 18  [memorial, medical, center, city, medical, center]
# 19  [department, water, irrigation, sewage, sanitation, resource, management]
#
#    bill_status
# 0   Pending
# 1   Passed
# 2   Passed
# 3   Pending
# 4   Pending
# 5   Pending
# 6   Pending
# 7   Passed
# 8   Pending
# 9   Pending
# 10  Pending
# 11  Pending
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18  Pending
# 19  Pending

# %%
df_billText.long_title.isna().sum()
# Out:
# 127

# %%
df_billText = df_billText.dropna(axis=0)
df_billText.shape
# Out:
# (14951, 3)

# %%
df_billText['long_title'] = df_billText.long_title.map(lambda words: 
                                                                [lemmatizer.lemmatize(word) for word in words])

# %%
df_billText['long_title'] = df_billText.long_title.apply(lambda x: ' '.join(x))
df_billText.head(2)
# Out:
#       bill_id  \
# 0  17SBN-2235
# 1  17SBN-2234
#
#                                                                  long_title  \
# 0  fiscal regime mining industry
# 1  sale certain land barangay city university city known university charter
#
#   bill_status
# 0  Pending
# 1  Passed

# %% [markdown]
# ## Word Vectorizer

# %%
# Vectorizers
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
v = TfidfVectorizer(stop_words="english")
data_v = v.fit_transform(df_billText.long_title)

# %%
data_dtm = pd.DataFrame(data_v.toarray(), columns=v.get_feature_names())
data_dtm.index = df_billText.index

# %%
df_vect_words = pd.DataFrame(sorted(v.vocabulary_.items(), key=lambda kv: kv[1], reverse=True),
                  columns = ['Word', 'Weight'])

# %%
df_vect_words.to_csv('vectorizer_voc.csv')

# %%
# Let's pickle it for later use
data_dtm.to_pickle("dtm.pkl")

# %%
df_billText.to_csv('billText_Processed.csv')
