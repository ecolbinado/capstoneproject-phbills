# %% [markdown]
# # bills_webscraper.ipynb

# %% [markdown]
# ### Import python packages

# %%
import warnings
warnings.filterwarnings('ignore')

import re, sqlite3, sys
from collections import OrderedDict

import requests
from bs4 import BeautifulSoup
import selenium.webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# ### Define Bill class

# %%
class Bill:
    
    def __init__(self, bill_id, num, link, congress, short_title, long_title, date_filed, scope, status, author,
                 subject, pri_committee, date_lastUpdate, logs, ra):
        self.bill_id = bill_id
        self.num = num
        self.link = link
        self.congress = congress
        self.short_title = short_title
        self.long_title = long_title
        self.date_filed = date_filed
        self.scope = scope
        self.status = status
        self.author = author
        self.subject = subject
        self.pri_committee = pri_committee
        self.date_lastUpdate = date_lastUpdate
        self.logs = logs
        self.ra = ra
        self.entities = (bill_id, num, link, congress, short_title, long_title, date_filed, scope, status, author,
                 subject, pri_committee, date_lastUpdate, logs, ra)
        
    def __str__(self):
        return 'Congress: ' + str(self.congress) + ' ' + self.num + ': ' + self.short_title
    
    def insert_bill():
        pass
    
    def update_bill():
        pass
    
    def remove_bill():
        pass

# %% [markdown]
# ### Compile Regex Patterns
# These regex patterns will be used to extract relevant strings only from the webscraping function.

# %%
bill_number_regex = re.compile(r'(?<=\d\d&q=).*')
filed_date_regex = re.compile(r'(?<=Filed on ).*(?= by )')
author_regex = re.compile(r'(?<= by ).*(?=\n)')
status_regex = re.compile(r'.*(?= \()')
last_update_regex = re.compile(r'(?<=\().*(?=\))')
logs_regex = re.compile(r'(?<=\n\[ \d\d\d\d \]\n).*(?=\(The (legislative history)|(LEGISLATIVE HISTORY))',re.DOTALL)
logs_wFootNote_regex = re.compile(r'(?<=\[ \d\d\d\d ]\n).*',re.DOTALL)
ra_regex = re.compile(r'(?<=\nRepublic Act No\. )\d*(?=(\n)| )',re.DOTALL)

# %% [markdown]
# ### Define Scraper functions
# getBill function is our main web scraping script. It follows the following workflow: <br>
# 1. Access Home URL of 'senate.gov.ph' <br>
# 2. Collect all the bills' links on that page.<br>
# 3. Iterate over the gathered links.<br>
# 4. Click the "All Information" button and then scrape all the bills' informations from that frame.<br>
# 5. Go to next page from the Home URL and repeat all steps again.<br>

# %% [markdown]
# #### bills_logScraper
# Scraper for special case of logs wherein the footnote is missing.

# %%
def bills_logScraper(logs):
    try:
        return logs_regex.search(logs).group()
    except AttributeError:
        try:
            return logs_wFootNote_regex.search(logs).group()
        except AttributeError:
            return 0

# %% [markdown]
# #### getBill function
# Our main scraping function.

# %%
def getBill(congress_num, page_num):
    
    driver = selenium.webdriver.PhantomJS()
    
    home_url = 'http://www.senate.gov.ph/lis/leg_sys.aspx?congress='+str(congress_num)+'&type=bill&p='+str(page_num)
    res = requests.get(home_url)
    res.raise_for_status()
    print('Accessing '+ 'http://www.senate.gov.ph' + ' ...\n')
    
    soup = BeautifulSoup(res.content, 'html.parser')
    sublinks=[str(bill.attrs['href']) for bill in soup.select('a') if 'bill_res' in str(bill.attrs['href'])]
    print('There are ' + str(len(sublinks)) + ' bills on this page, '+ 'p' + str(page_num) + '.\n')
    
    bills_dict = OrderedDict()
    fetch_errors = []
    for sublink in sublinks:
        #
        link = 'http://www.senate.gov.ph/lis/'+sublink
        num = bill_number_regex.search(sublink).group()
        print("Trying to access child link "+ link + ' ...')
        driver.get(link)
        driver.implicitly_wait(100)
        try:
            allInfo_btn = driver.find_element_by_xpath("//a[@id='lbAll']")
        except NoSuchElementException:
            print('\t' + str(num) + ' is missing! Skipping...\n')
            fetch_errors.append(num)
            continue
        
        allInfo_btn.click()
        element = WebDriverWait(driver,10).until(lambda x:x.find_element_by_xpath("//p[contains(text(),'Legislative History')]")) 
        soup_allinfo = BeautifulSoup(driver.page_source, 'html.parser')
        
        short_title = soup_allinfo.select('p[class="h1_bold"]')[0].getText()
        allinfo_frame_text = soup_allinfo.select('td[id="content"]')[0].getText()
        date_filed = filed_date_regex.search(allinfo_frame_text).group()
        author = author_regex.search(allinfo_frame_text).group()
        long_title = soup_allinfo.select('blockquote')[0].getText()
        scope = soup_allinfo.select('blockquote')[1].getText()
        
        legis_status = soup_allinfo.select('blockquote')[2].getText()
        blkqt_idx = 3 if 'HBN-' in legis_status else 2 # place holder for bills w/ "House counterpart bill no."
            
        legis_status = soup_allinfo.select('blockquote')[blkqt_idx].getText()
        status = status_regex.search(legis_status).group()
        date_lastUpdate = last_update_regex.search(legis_status).group()
        
        # Special case if a bill was 'Withdrawn.'
        if 'Withdrawn' in status:
            subject, pri_committee, logs, ra = ('','','','')
        else: 
            subject = soup_allinfo.select('blockquote')[blkqt_idx + 1].getText()       
            pri_committee = soup_allinfo.select('blockquote')[blkqt_idx + 2].getText()
        
            all_blkquotes = '\n'.join([soup_allinfo.select('blockquote')[i].
                               getText() for i in range(len(soup_allinfo.select('blockquote')))])        
            logs = bills_logScraper(all_blkquotes)

            try:
                ra = ra_regex.search(all_blkquotes).group()
            except AttributeError:
                ra = ''
        
        # Create unique id for this record.
        bill_id = str(congress_num) + str(num)
        bills_dict[bill_id]=(bill_id, num, link, congress_num, short_title, long_title, date_filed, scope, status, author,
                 subject, pri_committee, date_lastUpdate, logs, ra)
        print('\t' + str(num) + ' has been successfully scraped.\n')
        
    print('All Bills have been successfully scraped on this page.')
    # Must close the ghostDriver before exiting this function...
    driver.quit()
    
    return bills_dict, fetch_errors

# %% [markdown]
# ### Define getMax_page function
# This function will get the maximum/last page number of a Congressional Bill list.

# %%
def getMax_page(congress_num):
    driver = selenium.webdriver.PhantomJS()
    home_url = 'http://www.senate.gov.ph/lis/leg_sys.aspx?congress='+str(congress_num)+'&type=bill&p=999'
    driver.get(home_url)
    driver.implicitly_wait(100)
    soup_pagination = BeautifulSoup(driver.page_source, 'html.parser')
    
    maxPage = int(soup_pagination.select('div[class="lis_pagenav"] a')[-1].getText()) + 1
    
    driver.quit()
    return maxPage

# %% [markdown]
# ### Define Database functions
# These database functions will create a database connection instance. It will create table within the database, check for records, insert records, as well as update existing records.

# %%
def connect_db(database):
    try:
        conn = sqlite3.connect(database)
        cursor = conn.cursor()
        return conn, cursor
    except sqlite3.Error as error:
        print("Error in connecting to sqlite3", error)

def create_bills_table(conn, cursor):
    cursor.execute("""CREATE TABLE if not exists senateBills(
                    bill_id text PRIMARY KEY,
                    num text,
                    link text,
                    congress integer,
                    short_title text,
                    long_title text,
                    date_filed text,
                    scope text,
                    status integer,
                    author text,
                    subject text,
                    pri_committee text,
                    date_lastUpdate text,
                    logs text,
                    ra text)""")
    conn.commit()
    
def check_bill_exists(bill_id, conn, cursor):
    with conn:
        cursor.execute("SELECT bill_id FROM senateBills WHERE bill_id = (?)",(bill_id,))
    rows = cursor.fetchall()
    return True if len(rows) else False

def insert_bill(entities, conn, cursor):
    with conn:
        cursor.execute("""INSERT INTO senateBills(
                        bill_id, num, link, congress, short_title, long_title, date_filed, 
                        scope, status, author, subject, pri_committee, 
                        date_lastUpdate, logs, ra) VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""",(entities))
        conn.commit()
        
def update_date_lastUpdate(bill_id, date_lastUpdate, conn, cursor):
    with conn:
        cursor.execute("UPDATE senateBills SET date_lastUpdate = (?) WHERE bill_id = (?)",(date_lastUpdate, bill_id))
        conn.commit()

# %% [markdown]
# ### Define scrape_thisCongress function
# This function accepts nth Congress as an argument, _and where n is an integer,_ and scrapes through all the bills in all the available pages under that Congress.

# %%
def scrape_thisCongress(congress, start_page):
    pages = list(range(start_page, getMax_page(congress) + 1, 1))
    conn, cursor = connect_db('phBills.db')
    create_bills_table(conn, cursor)
    bill_count = 0
    scraping_failures = []
    for page in pages:
        thisPage_bills, scrape_failures = getBill(congress, page)
        scraping_failures.extend(scrape_failures)
        for bill, contents in thisPage_bills.items():
            some_bill = Bill(*contents)
            if check_bill_exists(some_bill.bill_id, conn, cursor):
                print(str(some_bill) + " already exists in our database. Updating 'date_lastUpdate' field instead.")
                update_date_lastUpdate(some_bill.bill_id, some_bill.date_lastUpdate, conn, cursor)
            else:
                insert_bill(some_bill.entities, conn, cursor)
            bill_count += 1
    print('\nCollected ' + str(bill_count) + ' bills from ' + str(congress) + 'th congress.')
    print('Disconnecting from http://www.senate.gov.ph...')
    conn.close()
    print('Done!')
    return bill_count, scraping_failures

# %% [markdown]
# ### Main Program

# %%
scrape_thisCongress(13, 155)
# Out:
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p155.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1450 ...
# 	SBN-1450 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1449 ...
# 	SBN-1449 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1448 ...
# 	SBN-1448 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1447 ...
# 	SBN-1447 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1446 ...
# 	SBN-1446 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1445 ...
# 	SBN-1445 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1444 ...
# 	SBN-1444 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1443 ...
# 	SBN-1443 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Congress: 13 SBN-1450: PROHIBITING FUND RAISING ACTIVITY FOR POLITICAL PURPOSES already exists in our database. Updating 'date_lastUpdate' field instead.
# Congress: 13 SBN-1449: FAMILY PRIVACY PROTECTION ACT already exists in our database. Updating 'date_lastUpdate' field instead.
# Congress: 13 SBN-1448: FAIR DEBT COLLECTION PRACTICES ACT already exists in our database. Updating 'date_lastUpdate' field instead.
# Congress: 13 SBN-1447: GIVING THE ACCUSED THE RIGHT TO APPLY FOR PROBATION already exists in our database. Updating 'date_lastUpdate' field instead.
# Congress: 13 SBN-1446: PARENTS AS FIRST TEACHERS CHALLENGE GRANT ACT already exists in our database. Updating 'date_lastUpdate' field instead.
# Congress: 13 SBN-1445: TIME FOR SCHOOLS ACT already exists in our database. Updating 'date_lastUpdate' field instead.
# Congress: 13 SBN-1444: ANTI-DISCRIMINATION IN COLLEGE ADMISSION ACT already exists in our database. Updating 'date_lastUpdate' field instead.
# Congress: 13 SBN-1443: PROFESSIONAL BOXING SAFETY ACT already exists in our database. Updating 'date_lastUpdate' field instead.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p156.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1442 ...
# 	SBN-1442 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1441 ...
# 	SBN-1441 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1440 ...
# 	SBN-1440 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1439 ...
# 	SBN-1439 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1438 ...
# 	SBN-1438 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1437 ...
# 	SBN-1437 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1436 ...
# 	SBN-1436 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1435 ...
# 	SBN-1435 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p157.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1434 ...
# 	SBN-1434 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1433 ...
# 	SBN-1433 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1432 ...
# 	SBN-1432 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1431 ...
# 	SBN-1431 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1430 ...
# 	SBN-1430 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1429 ...
# 	SBN-1429 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1428 ...
# 	SBN-1428 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1427 ...
# 	SBN-1427 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p158.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1426 ...
# 	SBN-1426 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1425 ...
# 	SBN-1425 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1424 ...
# 	SBN-1424 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1423 ...
# 	SBN-1423 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1422 ...
# 	SBN-1422 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1421 ...
# 	SBN-1421 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1420 ...
# 	SBN-1420 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1419 ...
# 	SBN-1419 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p159.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1418 ...
# 	SBN-1418 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1417 ...
# 	SBN-1417 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1416 ...
# 	SBN-1416 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1415 ...
# 	SBN-1415 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1414 ...
# 	SBN-1414 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1413 ...
# 	SBN-1413 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1412 ...
# 	SBN-1412 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1411 ...
# 	SBN-1411 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p160.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1410 ...
# 	SBN-1410 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1409 ...
# 	SBN-1409 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1408 ...
# 	SBN-1408 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1407 ...
# 	SBN-1407 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1406 ...
# 	SBN-1406 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1405 ...
# 	SBN-1405 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1404 ...
# 	SBN-1404 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1403 ...
# 	SBN-1403 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p161.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1402 ...
# 	SBN-1402 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1401 ...
# 	SBN-1401 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1400 ...
# 	SBN-1400 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1399 ...
# 	SBN-1399 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1398 ...
# 	SBN-1398 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1397 ...
# 	SBN-1397 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1396 ...
# 	SBN-1396 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1395 ...
# 	SBN-1395 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p162.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1394 ...
# 	SBN-1394 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1393 ...
# 	SBN-1393 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1392 ...
# 	SBN-1392 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1391 ...
# 	SBN-1391 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1390 ...
# 	SBN-1390 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1389 ...
# 	SBN-1389 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1388 ...
# 	SBN-1388 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1387 ...
# 	SBN-1387 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p163.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1386 ...
# 	SBN-1386 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1385 ...
# 	SBN-1385 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1384 ...
# 	SBN-1384 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1383 ...
# 	SBN-1383 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1382 ...
# 	SBN-1382 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-
has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-79 ...
# 	SBN-79 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-78 ...
# 	SBN-78 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-77 ...
# 	SBN-77 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-76 ...
# 	SBN-76 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-75 ...
# 	SBN-75 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p327.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-74 ...
# 	SBN-74 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-73 ...
# 	SBN-73 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-72 ...
# 	SBN-72 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-71 ...
# 	SBN-71 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-70 ...
# 	SBN-70 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-69 ...
# 	SBN-69 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-68 ...
# 	SBN-68 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-67 ...
# 	SBN-67 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p328.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-66 ...
# 	SBN-66 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-65 ...
# 	SBN-65 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-64 ...
# 	SBN-64 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-63 ...
# 	SBN-63 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-62 ...
# 	SBN-62 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-61 ...
# 	SBN-61 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-60 ...
# 	SBN-60 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-59 ...
# 	SBN-59 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p329.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-58 ...
# 	SBN-58 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-57 ...
# 	SBN-57 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-56 ...
# 	SBN-56 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-55 ...
# 	SBN-55 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-54 ...
# 	SBN-54 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-53 ...
# 	SBN-53 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-52 ...
# 	SBN-52 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-51 ...
# 	SBN-51 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p330.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-50 ...
# 	SBN-50 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-49 ...
# 	SBN-49 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-48 ...
# 	SBN-48 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-47 ...
# 	SBN-47 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-46 ...
# 	SBN-46 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-45 ...
# 	SBN-45 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-44 ...
# 	SBN-44 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-43 ...
# 	SBN-43 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p331.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-42 ...
# 	SBN-42 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-41 ...
# 	SBN-41 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-40 ...
# 	SBN-40 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-39 ...
# 	SBN-39 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-38 ...
# 	SBN-38 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-37 ...
# 	SBN-37 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-36 ...
# 	SBN-36 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-35 ...
# 	SBN-35 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p332.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-34 ...
# 	SBN-34 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-33 ...
# 	SBN-33 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-32 ...
# 	SBN-32 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-31 ...
# 	SBN-31 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-30 ...
# 	SBN-30 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-29 ...
# 	SBN-29 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-28 ...
# 	SBN-28 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-27 ...
# 	SBN-27 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p333.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-26 ...
# 	SBN-26 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-25 ...
# 	SBN-25 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-24 ...
# 	SBN-24 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-23 ...
# 	SBN-23 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-22 ...
# 	SBN-22 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-21 ...
# 	SBN-21 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-20 ...
# 	SBN-20 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-19 ...
# 	SBN-19 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p334.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-18 ...
# 	SBN-18 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-17 ...
# 	SBN-17 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-16 ...
# 	SBN-16 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-15 ...
# 	SBN-15 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-14 ...
# 	SBN-14 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-13 ...
# 	SBN-13 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-12 ...
# 	SBN-12 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-11 ...
# 	SBN-11 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 8 bills on this page, p335.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-10 ...
# 	SBN-10 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-9 ...
# 	SBN-9 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-8 ...
# 	SBN-8 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-7 ...
# 	SBN-7 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-6 ...
# 	SBN-6 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-5 ...
# 	SBN-5 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-4 ...
# 	SBN-4 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-3 ...
# 	SBN-3 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
# Accessing http://www.senate.gov.ph ...
#
# There are 2 bills on this page, p336.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-2 ...
# 	SBN-2 has been successfully scraped.
#
# Trying to access child link http://www.senate.gov.ph/lis/bill_res.aspx?congress=13&q=SBN-1 ...
# 	SBN-1 has been successfully scraped.
#
# All Bills have been successfully scraped on this page.
#
# Collected 1450 bills from 13th congress.
# Disconnecting from http://www.senate.gov.ph...
# Done!
# (1450, [])
