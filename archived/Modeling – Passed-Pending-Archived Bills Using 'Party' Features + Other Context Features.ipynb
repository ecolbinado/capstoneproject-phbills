# %% [markdown]
# # Modeling – Passed and Archived Bills Only Using 'Party' Feature

# %% [markdown]
# ## Importing Python Packages

# %%
# For loading, manipulating dataframe.
import pandas as pd
import sqlite3, datetime, sklearn

# Visualizations
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# Text Preprocessing
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer

# Sampling
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler 

# Vectorizers
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler

# Feature Processing 
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

# Modeling
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# Evaluation
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report

# Hide Warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
df_congress = pd.read_csv('congress_data_set.csv',index_col=0)

# %%
df_congress.shape
# Out:
# (15078, 22)

# %%
df_congress.head(2)
# Out:
#       bill_id       num  congress  \
# 0  17SBN-2235  SBN-2235        17
# 1  17SBN-2234  SBN-2234        17
#
#                                           long_title  date_filed     scope  \
# 0  an act establishing the fiscal regime for the ...  2019-05-28  National
# 1  an act authorizing the sale of certain parcels...  2019-05-27  National
#
#                                          status  \
# 0         Pending Second Reading, Special Order
# 1  Approved by the President of the Philippines
#
#                                               author date_lastUpdate  passed  \
# 0  Drilon, Franklin M., Recto, Ralph G., Sotto II...      2019-05-28   False
# 1  Recto, Ralph G., Sotto III, Vicente C., Escude...      2019-06-30    True
#
#    ...      Bloc Years of Service num_authors  delta_days  upper  mon  \
# 0  ...  Minority             24.0           4         0.0  False    5
# 1  ...  Majority             18.0           3        34.0  False    5
#
#    quarter  scope_national  majority_bloc  len_desc
# 0      2.0            True          False        61
# 1      2.0            True           True       300
#
# [2 rows x 22 columns]

# %%
# df_congress=df_congress[(df_congress.status=='Sent to the Archives') | (df_congress.passed==True)]
print(f"df_congress Data Points: {df_congress.shape[0]:,}")
# Out:
# df_congress Data Points: 15,078

# %%
df_congress.columns
# Out:
# Index(['bill_id', 'num', 'congress', 'long_title', 'date_filed', 'scope',
#        'status', 'author', 'date_lastUpdate', 'passed',
#        'Full Name Primary Author', 'Party', 'Bloc', 'Years of Service',
#        'num_authors', 'delta_days', 'upper', 'mon', 'quarter',
#        'scope_national', 'majority_bloc', 'len_desc'],
#       dtype='object')

# %%
cols_of_interest = ['Party','Years of Service','num_authors','delta_days','upper', 'mon', 'quarter',
       'scope_national', 'majority_bloc', 'len_desc','passed']
df_tocorr = df_congress[cols_of_interest]

# %%
df_tocorr.shape
# Out:
# (15078, 11)

# %%
columnsToEncode=df_tocorr.select_dtypes(include=[object]).columns
df_tocorr = pd.get_dummies(df_tocorr, columns=columnsToEncode, drop_first=True)

# %%
df_tocorr.shape
# Out:
# (15078, 24)

# %%
pd.options.display.max_columns = None

# %%
df_tocorr.corr()
# Out:
#                        Years of Service  num_authors  delta_days     upper  \
# Years of Service               1.000000     0.061176    0.050841  0.051702
# num_authors                    0.061176     1.000000    0.115971  0.088836
# delta_days                     0.050841     0.115971    1.000000  0.906815
# upper                          0.051702     0.088836    0.906815  1.000000
# mon                           -0.025919    -0.029448    0.014041  0.012563
# quarter                        0.005906    -0.051480    0.020326  0.014753
# scope_national                 0.100215     0.001802   -0.023326 -0.011375
# majority_bloc                  0.045473     0.035937    0.033741  0.028240
# len_desc                      -0.122234     0.045183    0.071377  0.062537
# passed                         0.047726     0.513843    0.225220  0.187966
# Party_Bagumbayan-VNP          -0.060310     0.034861    0.016334  0.013875
# Party_Independent             -0.208450    -0.018207    0.013784  0.018845
# Party_LDP                     -0.042210     0.019813    0.027818  0.018887
# Party_Lakas                   -0.029496    -0.016560   -0.007884 -0.007798
# Party_Lakas-CMD               -0.083944     0.014943    0.004537  0.008354
# Party_Lakas-Kampi-CMD         -0.145623    -0.006164    0.004736  0.000417
# Party_Liberal                 -0.093199     0.069302    0.036637  0.034312
# Party_NPC                      0.143544     0.043443    0.037379  0.036782
# Party_Nacionalista            -0.117751     0.031089    0.052840  0.044603
# Party_PDP-Laban                0.140967    -0.018218    0.002106 -0.012029
# Party_PDP–Laban               -0.024637     0.008902    0.015824  0.013991
# Party_PMP                     -0.188851    -0.018955   -0.015437 -0.016490
# Party_PRP                      0.556195    -0.073148   -0.103853 -0.090336
# Party_UNA                     -0.062415     0.002358   -0.022736 -0.009670
#
#                             mon   quarter  scope_national  majority_bloc  \
# Years of Service      -0.025919  0.005906        0.100215       0.045473
# num_authors           -0.029448 -0.051480        0.001802       0.035937
# delta_days             0.014041  0.020326       -0.023326       0.033741
# upper                  0.012563  0.014753       -0.011375       0.028240
# mon                    1.000000  0.940177       -0.107234       0.033186
# quarter                0.940177  1.000000       -0.085505       0.052842
# scope_national        -0.107234 -0.085505        1.000000      -0.068267
# majority_bloc          0.033186  0.052842       -0.068267       1.000000
# len_desc               0.020488  0.002321       -0.150979       0.048924
# passed                 0.006364 -0.015706       -0.000251       0.046367
# Party_Bagumbayan-VNP  -0.015743 -0.026212       -0.008296       0.057040
# Party_Independent      0.027458 -0.012211       -0.135730       0.222837
# Party_LDP             -0.037882 -0.046380        0.002002       0.057747
# Party_Lakas           -0.020462 -0.000227       -0.002467       0.017906
# Party_Lakas-CMD        0.011969 -0.018581       -0.026221       0.105664
# Party_Lakas-Kampi-CMD  0.002547 -0.001831       -0.028663       0.113565
# Party_Liberal         -0.023047 -0.030049        0.015063      -0.002651
# Party_NPC             -0.000888  0.012601        0.001945       0.184651
# Party_Nacionalista    -0.008337  0.049670       -0.004119      -0.100718
# Party_PDP-Laban       -0.053537 -0.117060        0.004571      -0.208826
# Party_PDP–Laban       -0.055045 -0.060324       -0.023674       0.084239
# Party_PMP              0.019026  0.027388        0.064498      -0.186846
# Party_PRP              0.047014  0.077969        0.086782      -0.126782
# Party_UNA             -0.002121 -0.015473        0.019944      -0.034047
#
#                        len_desc    passed  Party_Bagumbayan-VNP  \
# Years of Service      -0.122234  0.047726             -0.060310
# num_authors            0.045183  0.513843              0.034861
# delta_days             0.071377  0.225220              0.016334
# upper                  0.062537  0.187966              0.013875
# mon                    0.020488  0.006364             -0.015743
# quarter                0.002321 -0.015706             -0.026212
# scope_national        -0.150979 -0.000251             -0.008296
# majority_bloc          0.048924  0.046367              0.057040
# len_desc               1.000000  0.081711             -0.006845
# passed                 0.081711  1.000000              0.014214
# Party_Bagumbayan-VNP  -0.006845  0.014214              1.000000
# Party_Independent      0.048940  0.020719             -0.040963
# Party_LDP              0.012716  0.031227             -0.017359
# Party_Lakas            0.017081 -0.013351             -0.014381
# Party_Lakas-CMD        0.027925 -0.013608             -0.012866
# Party_Lakas-Kampi-CMD  0.016176  0.000646             -0.013828
# Party_Liberal          0.057267  0.034432             -0.024373
# Party_NPC              0.039555  0.044413             -0.022484
# Party_Nacionalista     0.038458  0.026381             -0.028118
# Party_PDP-Laban        0.025164 -0.018938             -0.015482
# Party_PDP–Laban        0.046770  0.030826             -0.010257
# Party_PMP              0.042824 -0.032079             -0.036260
# Party_PRP             -0.243092 -0.071327             -0.041517
# Party_UNA              0.013602 -0.003395             -0.011485
#
#                        Party_Independent  Party_LDP  Party_Lakas  \
# Years of Service               -0.208450  -0.042210    -0.029496
# num_authors                    -0.018207   0.019813    -0.016560
# delta_days                      0.013784   0.027818    -0.007884
# upper                           0.018845   0.018887    -0.007798
# mon                             0.027458  -0.037882    -0.020462
# quarter                        -0.012211  -0.046380    -0.000227
# scope_national                 -0.135730   0.002002    -0.002467
# majority_bloc                   0.222837   0.057747     0.017906
# len_desc                        0.048940   0.012716     0.017081
# passed                          0.020719   0.031227    -0.013351
# Party_Bagumbayan-VNP           -0.040963  -0.017359    -0.014381
# Party_Independent               1.000000  -0.102384    -0.084819
# Party_LDP                      -0.102384   1.000000    -0.035944
# Party_Lakas                    -0.084819  -0.035944     1.000000
# Party_Lakas-CMD                -0.075883  -0.032157    -0.026640
# Party_Lakas-Kampi-CMD          -0.081558  -0.034562    -0.028633
# Party_Liberal                  -0.143749  -0.060917    -0.050466
# Party_NPC                      -0.132609  -0.056196    -0.046555
# Party_Nacionalista             -0.165840  -0.070279    -0.058221
# Party_PDP-Laban                -0.091312  -0.038696    -0.032057
# Party_PDP–Laban                -0.060497  -0.025637    -0.021239
# Party_PMP                      -0.213860  -0.090629    -0.075080
# Party_PRP                      -0.244868  -0.103769    -0.085966
# Party_UNA                      -0.067735  -0.028705    -0.023780
#
#                        Party_Lakas-CMD  Party_Lakas-Kampi-CMD  Party_Liberal  \
# Years of Service             -0.083944              -0.145623      -0.093199
# num_authors                   0.014943              -0.006164       0.069302
# delta_days                    0.004537               0.004736       0.036637
# upper                         0.008354               0.000417       0.034312
# mon                           0.011969               0.002547      -0.023047
# quarter                      -0.018581              -0.001831      -0.030049
# scope_national               -0.026221              -0.028663       0.015063
# majority_bloc                 0.105664               0.113565      -0.002651
# len_desc                      0.027925               0.016176       0.057267
# passed                       -0.013608               0.000646       0.034432
# Party_Bagumbayan-VNP         -0.012866              -0.013828      -0.024373
# Party_Independent            -0.075883              -0.081558      -0.143749
# Party_LDP                    -0.032157              -0.034562      -0.060917
# Party_Lakas                  -0.026640              -0.028633      -0.050466
# Party_Lakas-CMD               1.000000              -0.025616      -0.045150
# Party_Lakas-Kampi-CMD        -0.025616               1.000000      -0.048526
# Party_Liberal                -0.045150              -0.048526       1.000000
# Party_NPC                    -0.041650              -0.044765      -0.078900
# Party_Nacionalista           -0.052088              -0.055983      -0.098673
# Party_PDP-Laban              -0.028680              -0.030825      -0.054330
# Party_PDP–Laban              -0.019001              -0.020422      -0.035995
# Party_PMP                    -0.067170              -0.072193      -0.127244
# Party_PRP                    -0.076909              -0.082661      -0.145693
# Party_UNA                    -0.021275              -0.022866      -0.040302
#
#                        Party_NPC  Party_Nacionalista  Party_PDP-Laban  \
# Years of Service        0.143544           -0.117751         0.140967
# num_authors             0.043443            0.031089        -0.018218
# delta_days              0.037379            0.052840         0.002106
# upper                   0.036782            0.044603        -0.012029
# mon                    -0.000888           -0.008337        -0.053537
# quarter                 0.012601            0.049670        -0.117060
# scope_national          0.001945           -0.004119         0.004571
# majority_bloc           0.184651           -0.100718        -0.208826
# len_desc                0.039555            0.038458         0.025164
# passed                  0.044413            0.026381        -0.018938
# Party_Bagumbayan-VNP   -0.022484           -0.028118        -0.015482
# Party_Independent      -0.132609           -0.165840        -0.091312
# Party_LDP              -0.056196           -0.070279        -0.038696
# Party_Lakas            -0.046555           -0.058221        -0.032057
# Party_Lakas-CMD        -0.041650           -0.052088        -0.028680
# Party_Lakas-Kampi-CMD  -0.044765           -0.055983        -0.030825
# Party_Liberal          -0.078900           -0.098673        -0.054330
# Party_NPC               1.000000           -0.091025        -0.050119
# Party_Nacionalista     -0.091025            1.000000        -0.062679
# Party_PDP-Laban        -0.050119           -0.062679         1.000000
# Party_PDP–Laban        -0.033205           -0.041526        -0.022865
# Party_PMP              -0.117382           -0.146798        -0.080828
# Party_PRP              -0.134402           -0.168082        -0.092547
# Party_UNA              -0.037178           -0.046495        -0.025600
#
#                        Party_PDP–Laban  Party_PMP  Party_PRP  Party_UNA
# Years of Service             -0.024637  -0.188851   0.556195  -0.062415
# num_authors                   0.008902  -0.018955  -0.073148   0.002358
# delta_days                    0.015824  -0.015437  -0.103853  -0.022736
# upper                         0.013991  -0.016490  -0.090336  -0.009670
# mon                          -0.055045   0.019026   0.047014  -0.002121
# quarter                      -0.060324   0.027388   0.077969  -0.015473
# scope_national               -0.023674   0.064498   0.086782   0.019944
# majority_bloc                 0.084239  -0.186846  -0.126782  -0.034047
# len_desc                      0.046770   0.042824  -0.243092   0.013602
# passed                        0.030826  -0.032079  -0.071327  -0.003395
# Party_Bagumbayan-VNP         -0.010257  -0.036260  -0.041517  -0.011485
# Party_Independent            -0.060497  -0.213860  -0.244868  -0.067735
# Party_LDP                    -0.025637  -0.090629  -0.103769  -0.028705
# Party_Lakas                  -0.021239  -0.075080  -0.085966  -0.023780
# Party_Lakas-CMD              -0.019001  -0.067170  -0.076909  -0.021275
# Party_Lakas-Kampi-CMD        -0.020422  -0.072193  -0.082661  -0.022866
# Party_Liberal                -0.035995  -0.127244  -0.145693  -0.040302
# Party_NPC                    -0.033205  -0.117382  -0.134402  -0.037178
# Party_Nacionalista           -0.041526  -0.146798  -0.168082  -0.046495
# Party_PDP-Laban              -0.022865  -0.080828  -0.092547  -0.025600
# Party_PDP–Laban               1.000000  -0.053551  -0.061315  -0.016961
# Party_PMP                    -0.053551   1.000000  -0.216752  -0.059958
# Party_PRP                    -0.061315  -0.216752   1.000000  -0.068651
# Party_UNA                    -0.016961  -0.059958  -0.068651   1.000000

# %%
X = df_tocorr.drop('passed',axis=1)

# %%
X.shape
# Out:
# (15078, 23)

# %%
y = df_tocorr['passed']

# %%
y.shape
# Out:
# (15078,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=43)

# %%
print(f"Our new train set has {X_train.shape[0]} data points, {np.sum(y_train)} of which are actual positives.")
# Out:
# Our new train set has 11308 data points, 321 of which are actual positives.

# %%
svc = SVC(gamma='auto', kernel='linear', random_state = 42)
svc.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#     max_iter=-1, probability=False, random_state=42, shrinking=True, tol=0.001,
#     verbose=False)

# %%
predicted = svc.predict(X_test)

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.99      3653
#         True       0.69      0.17      0.27       117
#
#     accuracy                           0.97      3770
#    macro avg       0.83      0.58      0.63      3770
# weighted avg       0.97      0.97      0.96      3770
